# %% [markdown]
# <a href="https://colab.research.google.com/github/qorinda/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Image/kitten01.jpeg')
plt.imshow(img)       # perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) # konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Image/kitten01.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# simpan file image
# cv.imwrite('/content/drive/MyDrive/PCVK_MM/Image/mandrill2.tiff',img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))     # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
# perhatikan koordinat titik" pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#Tugas 1
#Tampilkan image dalam channel Red-Green dan Green-Blue saja!
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
#Tugas 2
#Tampilkan image baris ke 10-100, kolom 10-100!
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
#Tugas 3
#Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
plt.imshow(img[5:30])

# %%
#Tugas 4
#Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(200,200), pt2=(20,150), color=(0,255,255), thickness=3)
cv.rectangle(img_ktk, pt1=(148,63), pt2=(21,148), color=(0,255,0),thickness=3)
cv.rectangle(img_ktk, pt1=(25,100), pt2=(100,50), color=(255,255,255),thickness=3)
cv.rectangle(img_ktk, pt1=(148,61), pt2=(200,148), color=(255,0,0),thickness=3)
cv.rectangle(img_ktk, pt1=(25,60), pt2=(170,25), color=(0,0,255),thickness=3)
plt.imshow(img_ktk)

# %%
#Tugas 5
#Tampilkan image dengan posisi terbalik!
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
#Tugas 6
#Buat rectangle dan circle pada bagian wajah dari image kitten!

img_a = cv.imread('/content/drive/MyDrive/PCVK_MM/Image/kitten01.jpeg')
cv.rectangle(img_a,pt1=(105,90),pt2=(170,40),color=(0,0,255),thickness=3)
plt.imshow(img_a)

# %%
#Tugas 6 (2)
cv.circle(img_a,center=(140,65),radius=20,color=(255,0,255),thickness=2)
plt.imshow(img_a)

# %%
#Tugas 7
#Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Image/kitten01.jpeg')
plt.imshow(img)

# %%
#Tugas 7 (2)
img_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
#Tugas 7 (3)
cv.rectangle(img_rgb,pt1=(100,400),pt2=(10,500),color=(0,255,0),thickness=10)
plt.imshow(img_rgb)

# %% [markdown]
# **Pertanyaan**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib
#
#   **Jawaban :**
#
#   Matplotlib bisa memudahkan dalam membuat grafik yang rapi dengan cara yg mudah dan juga bisa mengisi parameter terhadap grafik tersebut
#
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
#
#   **Jawaban** :
#
#   •	Int16 Ini adalah FCL type. Dalam C#, pendek dipetakan ke Int16. Ini adalah jenis nilai dan mewakili Sistem.Int16 struct.Hal ini ditandatangani dan membutuhkan 16 bit.Memiliki minimal -32768 dan maksimum +32767 nilai.
#
#   •	Int32Ini adalah FCL type.Dalam C#, int dipetakan ke Int32.Ini adalah jenis nilai dan mewakili Sistem.Int32 struct.Hal ini ditandatangani dan membutuhkan 32 bit Memiliki minimal -2147483648 dan maksimum +2147483647 nilai
#
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
#
#   **Jawaban** :
#
#    Untuk mengatur tata letak ukuran
#
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
#
#   **Jawaban** :
#
#   Menampilkan gambar secara otomatis dari google drive tetapi warnanya berbalik menjadi BGR
#
# 5. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 4
#
#   **Jawaban** :
#
#   Untuk menyediakan fungsi konversi untuk gambar
